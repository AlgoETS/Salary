# %%
# read pickle file
# get current working directory
import os
os.getcwd()
import pickle
import pandas as pd
import polars as pl
with open("data/pickle/salary_guide_2024_1.pkl", 'rb') as f:
    data = pickle.load(f)

# load to dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#                       province                   region  \
# 0                      alberta
# 1                      alberta
# 2                      alberta
# 3                      alberta
# 4                      alberta
# ...                        ...                      ...
# 15503  newfoundland & labrador  saguenay-lac-saint-jean
# 15504  newfoundland & labrador  saguenay-lac-saint-jean
# 15505  newfoundland & labrador  saguenay-lac-saint-jean
# 15506  newfoundland & labrador  saguenay-lac-saint-jean
# 15507  newfoundland & labrador  saguenay-lac-saint-jean
#
#                                                     job       entry  \
# 0                  agent·e d’assistance voyage bilingue   47,7-68,2
# 1                        agent·e de clavardage bilingue   52,6-75,8
# 2                 agent·e de prise de commande bilingue   40,8-59,7
# 3         agent·e de rétention de la clientèle bilingue   42,4-65,2
# 4                           agent·e de sondage bilingue   38,5-60,1
# ...                                                 ...         ...
# 15503  gestionnaire du contrôle/assurance de la qualité  83,4-128,2
# 15504                      programmeur/programmeuse erp  72,1-106,8
# 15505                quality assurance analyst - manual   62,7-97,4
# 15506                 testeur/testeuse d’automatisation  75,0-110,0
# 15507                           testeur/testeuse manuel   48,4-76,9
#
#               mid       senior
# 0       53,5-68,2    59,7-75,7
# 1       58,5-75,8    65,7-85,2
# 2       47,0-59,7    52,9-66,1
# 3       49,0-65,2    56,0-74,3
# 4       46,6-60,1    53,3-65,9
# ...           ...          ...
# 15503  94,9-128,2  108,7-145,4
# 15504  80,7-106,8   91,5-121,3
# 15505   72,4-97,4   83,6-110,9
# 15506  95,0-110,0  115,0-125,0
# 15507   56,7-76,9    66,1-87,7
#
# [15508 rows x 6 columns]

# %%
# Split the salary ranges into minimum and maximum salaries
df[['entry_min', 'entry_max']] = df['entry'].str.replace(',', '.').str.split('-', expand=True).astype(float)
df[['mid_min', 'mid_max']] = df['mid'].str.replace(',', '.').str.split('-', expand=True).astype(float)
df[['senior_min', 'senior_max']] = df['senior'].str.replace(',', '.').str.split('-', expand=True).astype(float)

# Create a new column with the maximum salary for each job
df['max_salary'] = df[['entry_max', 'mid_max', 'senior_max']].max(axis=1)
#calculate the mean for each level
df['entry_mean'] = df[['entry_min', 'entry_max']].mean(axis=1)
df['mid_mean'] = df[['mid_min', 'mid_max']].mean(axis=1)
df['senior_mean'] = df[['senior_min', 'senior_max']].mean(axis=1)

# Sort the DataFrame by the maximum salary in descending order
df_sorted = df.sort_values('max_salary', ascending=False)

# Get the job that pays the most
job_highest_paid = df_sorted['job'].iloc[0]

print(f"The job that pays the most is {job_highest_paid}")
# Out:
# The job that pays the most is chef/cheffe de la direction financière

# %%
df_sorted.head()
# Out:
#                province                        region  \
# 1746   british columbia                 fraser valley
# 14126            québec                      montréal
# 13548            québec  montérégie - les maskoutains
# 12671            québec                      mauricie
# 11905            québec                         laval
#
#                                           job        entry          mid  \
# 1746   chef/cheffe de la direction financière  178,8-453,0  260,4-453,0
# 14126  chef/cheffe de la direction financière  176,5-451,3  258,6-451,3
# 13548  chef/cheffe de la direction financière  175,3-448,2  256,9-448,2
# 12671  chef/cheffe de la direction financière  175,3-448,2  256,9-448,2
# 11905  chef/cheffe de la direction financière  174,1-447,0  255,5-447,0
#
#             senior  entry_min  entry_max  mid_min  mid_max  senior_min  \
# 1746   362,7-630,8      178.8      453.0    260.4    453.0       362.7
# 14126  360,9-629,4      176.5      451.3    258.6    451.3       360.9
# 13548  358,5-624,4      175.3      448.2    256.9    448.2       358.5
# 12671  358,5-624,4      175.3      448.2    256.9    448.2       358.5
# 11905  357,2-624,0      174.1      447.0    255.5    447.0       357.2
#
#        senior_max  max_salary  entry_mean  mid_mean  senior_mean
# 1746        630.8       630.8      315.90    356.70       496.75
# 14126       629.4       629.4      313.90    354.95       495.15
# 13548       624.4       624.4      311.75    352.55       491.45
# 12671       624.4       624.4      311.75    352.55       491.45
# 11905       624.0       624.0      310.55    351.25       490.60

# %%
df_sorted.head(100)
# Out:
#                province                        region  \
# 1746   british columbia                 fraser valley
# 14126            québec                      montréal
# 13548            québec  montérégie - les maskoutains
# 12671            québec                      mauricie
# 11905            québec                         laval
# ...                 ...                           ...
# 14125            québec                      montréal
# 11695            québec                   laurentides
# 1748   british columbia                 fraser valley
# 6406            ontario                     cambridge
# 2761   british columbia                  surrey/delta
#
#                                                      job        entry  \
# 1746              chef/cheffe de la direction financière  178,8-453,0
# 14126             chef/cheffe de la direction financière  176,5-451,3
# 13548             chef/cheffe de la direction financière  175,3-448,2
# 12671             chef/cheffe de la direction financière  175,3-448,2
# 11905             chef/cheffe de la direction financière  174,1-447,0
# ...                                                  ...          ...
# 14125                  directeur/directrice des finances  152,8-257,3
# 11695                  vice président marketing & ventes   89,3-228,3
# 1748                 vice-président·e de l’audit interne  156,2-256,7
# 6406                 vice-président·e de l’audit interne  157,3-257,8
# 2761   directeur/directrice - budget et performance f...  155,7-256,0
#
#                mid       senior  entry_min  entry_max  mid_min  mid_max  \
# 1746   260,4-453,0  362,7-630,8      178.8      453.0    260.4    453.0
# 14126  258,6-451,3  360,9-629,4      176.5      451.3    258.6    451.3
# 13548  256,9-448,2  358,5-624,4      175.3      448.2    256.9    448.2
# 12671  256,9-448,2  358,5-624,4      175.3      448.2    256.9    448.2
# 11905  255,5-447,0  357,2-624,0      174.1      447.0    255.5    447.0
# ...            ...          ...        ...        ...      ...      ...
# 14125  196,6-257,3  238,7-312,2      152.8      257.3    196.6    257.3
# 11695  125,2-228,3  171,0-311,6       89.3      228.3    125.2    228.3
# 1748   194,8-256,7  235,3-310,7      156.2      256.7    194.8    256.7
# 6406   196,3-257,8  236,9-310,7      157.3      257.8    196.3    257.8
# 2761   196,6-256,0  238,2-310,6      155.7      256.0    196.6    256.0
#
#        senior_min  senior_max  max_salary  entry_mean  mid_mean  senior_mean
# 1746        362.7       630.8       630.8      315.90    356.70       496.75
# 14126       360.9       629.4       629.4      313.90    354.95       495.15
# 13548       358.5       624.4       624.4      311.75    352.55       491.45
# 12671       358.5       624.4       624.4      311.75    352.55       491.45
# 11905       357.2       624.0       624.0      310.55    351.25       490.60
# ...           ...         ...         ...         ...       ...          ...
# 14125       238.7       312.2       312.2      205.05    226.95       275.45
# 11695       171.0       311.6       311.6      158.80    176.75       241.30
# 1748        235.3       310.7       310.7      206.45    225.75       273.00
# 6406        236.9       310.7       310.7      207.55    227.05       273.80
# 2761        238.2       310.6       310.6      205.85    226.30       274.40
#
# [100 rows x 16 columns]

# %% [markdown]
# ### Get the engineering jobs that pay the most

# %%
top_engineers_jobs=df_sorted[df_sorted['job'].str.contains('ingénieur', case=False)]
top_engineers_jobs.head(30)
# Out:
#                province                   region  \
# 125             alberta
# 190             alberta
# 532             alberta                 red deer
# 597             alberta                 red deer
# 7576            ontario                cambridge
# 9008            ontario                cambridge
# 14449            québec                 montréal
# 71              alberta
# 130             alberta
# 9017            ontario                cambridge
# 14474            québec                 montréal
# 7377            ontario                cambridge
# 7313            ontario                cambridge
# 1995   british columbia            fraser valley
# 12207            québec                    laval
# 14797            québec  saguenay-lac-saint-jean
# 12949            québec                 mauricie
# 10423            québec                cambridge
# 1002            alberta                 red deer
# 194             alberta
# 1844   british columbia            fraser valley
# 131             alberta
# 72              alberta
# 12232            québec                    laval
# 2016   british columbia            fraser valley
# 2876   british columbia             surrey/delta
# 2941   british columbia             surrey/delta
# 9893            ontario                cambridge
# 12974            québec                 mauricie
# 10448            québec                cambridge
#
#                                         job        entry          mid  \
# 125                    ingénieur·e chimiste   83,2-151,1  105,7-151,1
# 190                    ingénieur·e chimiste   83,2-151,1  105,7-151,1
# 532                    ingénieur·e chimiste   79,0-144,6  100,5-144,6
# 597                    ingénieur·e chimiste   79,0-144,6  100,5-144,6
# 7576                   ingénieur·e chimiste   77,7-142,7   98,9-142,7
# 9008             ingénieur·e d’applications   93,2-144,4  107,6-144,4
# 14449       ingénieur·e de données massives   96,0-143,7  107,6-143,7
# 71              ingénieur·e de projet civil   88,1-140,6  101,6-140,6
# 130             ingénieur·e de projet civil   88,1-140,6  101,6-140,6
# 9017   ingénieur·e en amélioration continue   97,8-144,7  109,1-144,7
# 14474              ingénieur·e infonuagique   89,0-142,2  104,9-142,2
# 7377             ingénieur·e d’applications   92,1-142,6  106,3-142,6
# 7313             ingénieur·e d’applications   92,1-142,6  106,3-142,6
# 1995        ingénieur·e de données massives   96,0-142,4  107,3-142,4
# 12207       ingénieur·e de données massives   94,9-142,2  106,4-142,2
# 14797       ingénieur·e de données massives   94,9-142,2  106,4-142,2
# 12949       ingénieur·e de données massives   94,9-142,2  106,4-142,2
# 10423       ingénieur·e de données massives   94,9-142,2  106,4-142,2
# 1002                   ingénieur·e chimiste   76,3-138,8   96,7-138,8
# 194                  ingénieur·e de projets  102,4-143,5  110,8-143,5
# 1844                   ingénieur·e chimiste   75,8-138,6   96,2-138,6
# 131                  ingénieur·e de projets  102,4-143,5  110,8-143,5
# 72                   ingénieur·e de projets  102,4-143,5  110,8-143,5
# 12232              ingénieur·e infonuagique   88,0-140,7  103,7-140,7
# 2016               ingénieur·e infonuagique   89,2-141,0  104,7-141,0
# 2876                   ingénieur·e chimiste   75,6-138,3   96,0-138,3
# 2941                   ingénieur·e chimiste   75,6-138,3   96,0-138,3
# 9893                   ingénieur·e chimiste   75,4-137,9   95,7-137,9
# 12974              ingénieur·e infonuagique   87,6-140,3  103,3-140,3
# 10448              ingénieur·e infonuagique   87,6-140,3  103,3-140,3
#
#             senior  entry_min  entry_max  mid_min  mid_max  senior_min  \
# 125    128,9-173,0       83.2      151.1    105.7    151.1       128.9
# 190    128,9-173,0       83.2      151.1    105.7    151.1       128.9
# 532    123,0-166,2       79.0      144.6    100.5    144.6       123.0
# 597    123,0-166,2       79.0      144.6    100.5    144.6       123.0
# 7576   121,2-164,4       77.7      142.7     98.9    142.7       121.2
# 9008   124,6-162,5       93.2      144.4    107.6    144.4       124.6
# 14449  122,1-161,7       96.0      143.7    107.6    143.7       122.1
# 71     117,7-161,2       88.1      140.6    101.6    140.6       117.7
# 130    117,7-161,2       88.1      140.6    101.6    140.6       117.7
# 9017   122,8-161,0       97.8      144.7    109.1    144.7       122.8
# 14474  122,8-160,6       89.0      142.2    104.9    142.2       122.8
# 7377   123,1-160,5       92.1      142.6    106.3    142.6       123.1
# 7313   123,1-160,5       92.1      142.6    106.3    142.6       123.1
# 1995   121,4-160,2       96.0      142.4    107.3    142.4       121.4
# 12207  120,8-160,1       94.9      142.2    106.4    142.2       120.8
# 14797  120,8-160,1       94.9      142.2    106.4    142.2       120.8
# 12949  120,8-160,1       94.9      142.2    106.4    142.2       120.8
# 10423  120,8-160,1       94.9      142.2    106.4    142.2       120.8
# 1002   118,1-159,4       76.3      138.8     96.7    138.8       118.1
# 194    121,9-159,3      102.4      143.5    110.8    143.5       121.9
# 1844   117,8-159,3       75.8      138.6     96.2    138.6       117.8
# 131    121,9-159,3      102.4      143.5    110.8    143.5       121.9
# 72     121,9-159,3      102.4      143.5    110.8    143.5       121.9
# 12232  121,4-159,0       88.0      140.7    103.7    140.7       121.4
# 2016   122,0-159,0       89.2      141.0    104.7    141.0       122.0
# 2876   117,5-158,9       75.6      138.3     96.0    138.3       117.5
# 2941   117,5-158,9       75.6      138.3     96.0    138.3       117.5
# 9893   117,2-158,5       75.4      137.9     95.7    137.9       117.2
# 12974  121,0-158,5       87.6      140.3    103.3    140.3       121.0
# 10448  121,0-158,5       87.6      140.3    103.3    140.3       121.0
#
#        senior_max  max_salary  entry_mean  mid_mean  senior_mean
# 125         173.0       173.0      117.15    128.40       150.95
# 190         173.0       173.0      117.15    128.40       150.95
# 532         166.2       166.2      111.80    122.55       144.60
# 597         166.2       166.2      111.80    122.55       144.60
# 7576        164.4       164.4      110.20    120.80       142.80
# 9008        162.5       162.5      118.80    126.00       143.55
# 14449       161.7       161.7      119.85    125.65       141.90
# 71          161.2       161.2      114.35    121.10       139.45
# 130         161.2       161.2      114.35    121.10       139.45
# 9017        161.0       161.0      121.25    126.90       141.90
# 14474       160.6       160.6      115.60    123.55       141.70
# 7377        160.5       160.5      117.35    124.45       141.80
# 7313        160.5       160.5      117.35    124.45       141.80
# 1995        160.2       160.2      119.20    124.85       140.80
# 12207       160.1       160.1      118.55    124.30       140.45
# 14797       160.1       160.1      118.55    124.30       140.45
# 12949       160.1       160.1      118.55    124.30       140.45
# 10423       160.1       160.1      118.55    124.30       140.45
# 1002        159.4       159.4      107.55    117.75       138.75
# 194         159.3       159.3      122.95    127.15       140.60
# 1844        159.3       159.3      107.20    117.40       138.55
# 131         159.3       159.3      122.95    127.15       140.60
# 72          159.3       159.3      122.95    127.15       140.60
# 12232       159.0       159.0      114.35    122.20       140.20
# 2016        159.0       159.0      115.10    122.85       140.50
# 2876        158.9       158.9      106.95    117.15       138.20
# 2941        158.9       158.9      106.95    117.15       138.20
# 9893        158.5       158.5      106.65    116.80       137.85
# 12974       158.5       158.5      113.95    121.80       139.75
# 10448       158.5       158.5      113.95    121.80       139.75

# %% [markdown]
# ### get the engineers jobs that pay the least

# %%
worst_engineers_jobs=top_engineers_jobs.sort_values('max_salary', ascending=True)
worst_engineers_jobs.head(30)
# Out:
#                province                         region  \
# 10622            québec               centre-du-québec
# 5046            ontario                      cambridge
# 7911            ontario                      cambridge
# 3439           manitoba         queens - charlottetown
# 3375           manitoba         queens - charlottetown
# 5201            ontario                      cambridge
# 6249            ontario                      cambridge
# 6912            ontario                      cambridge
# 4943            ontario                      cambridge
# 10625            québec               centre-du-québec
# 6021            ontario                      cambridge
# 4728            ontario                      cambridge
# 8233            ontario                      cambridge
# 8297            ontario                      cambridge
# 11243            québec                         estrie
# 13117            québec  montérégie - brome-missisquoi
# 1581   british columbia                  fraser valley
# 1517   british columbia                  fraser valley
# 14225            québec                       montréal
# 4484            ontario                      cambridge
# 4420            ontario                      cambridge
# 8634            ontario                      cambridge
# 2159   british columbia                  fraser valley
# 9705            ontario                      cambridge
# 13647            québec   montérégie - les maskoutains
# 5397            ontario                      cambridge
# 12403            québec                       mauricie
# 13353            québec  montérégie - la haute-yamaska
# 5693            ontario                      cambridge
# 9346            ontario                      cambridge
#
#                                  job      entry        mid     senior  \
# 10622  ingénieur·e de machines fixes  51,6-73,5  56,5-73,5  62,8-82,1
# 5046   ingénieur·e de machines fixes  54,0-76,6  59,2-76,6  65,6-85,2
# 7911   ingénieur·e de machines fixes  55,1-78,0  60,3-78,0  66,8-86,8
# 3439   ingénieur·e de machines fixes  54,6-78,2  60,0-78,2  66,7-87,2
# 3375   ingénieur·e de machines fixes  54,6-78,2  60,0-78,2  66,7-87,2
# 5201   ingénieur·e de machines fixes  55,3-78,5  60,6-78,5  67,2-87,3
# 6249   ingénieur·e de machines fixes  55,5-78,6  60,8-78,6  67,3-87,4
# 6912   ingénieur·e de machines fixes  55,7-78,9  61,0-78,9  67,6-87,7
# 4943   ingénieur·e de machines fixes  55,6-78,9  60,9-78,9  67,5-87,9
# 10625         ingénieur·e de service  50,7-76,0  56,6-76,0  64,5-88,0
# 6021   ingénieur·e de machines fixes  56,0-79,4  61,4-79,4  68,0-88,4
# 4728   ingénieur·e de machines fixes  56,2-79,6  61,6-79,6  68,3-88,6
# 8233   ingénieur·e de machines fixes  56,4-80,0  61,8-80,0  68,5-88,9
# 8297   ingénieur·e de machines fixes  56,4-80,0  61,8-80,0  68,5-88,9
# 11243         ingénieur·e de service  51,2-76,8  57,3-76,8  65,2-88,9
# 13117         ingénieur·e de service  51,3-77,0  57,4-77,0  65,3-89,0
# 1581   ingénieur·e de machines fixes  56,5-80,0  61,9-80,0  68,5-89,0
# 1517   ingénieur·e de machines fixes  56,5-80,0  61,9-80,0  68,5-89,0
# 14225  ingénieur·e de machines fixes  55,8-79,9  61,3-79,9  68,2-89,0
# 4484   ingénieur·e de machines fixes  56,4-80,2  61,9-80,2  68,6-89,2
# 4420   ingénieur·e de machines fixes  56,4-80,2  61,9-80,2  68,6-89,2
# 8634   ingénieur·e de machines fixes  56,5-80,2  62,0-80,2  68,7-89,3
# 2159   ingénieur·e de machines fixes  56,7-80,4  62,2-80,4  68,9-89,4
# 9705   ingénieur·e de machines fixes  56,5-80,4  62,0-80,4  68,8-89,5
# 13647         ingénieur·e de service  51,7-77,5  57,8-77,5  65,8-89,6
# 5397   ingénieur·e de machines fixes  56,7-80,5  62,2-80,5  68,9-89,6
# 12403         ingénieur·e de service  51,6-77,6  57,8-77,6  65,8-89,7
# 13353         ingénieur·e de service  51,8-77,8  58,0-77,8  66,0-90,0
# 5693   ingénieur·e de machines fixes  57,1-80,9  62,5-80,9  69,3-90,0
# 9346   ingénieur·e de machines fixes  56,9-80,9  62,4-80,9  69,2-90,0
#
#        entry_min  entry_max  mid_min  mid_max  senior_min  senior_max  \
# 10622       51.6       73.5     56.5     73.5        62.8        82.1
# 5046        54.0       76.6     59.2     76.6        65.6        85.2
# 7911        55.1       78.0     60.3     78.0        66.8        86.8
# 3439        54.6       78.2     60.0     78.2        66.7        87.2
# 3375        54.6       78.2     60.0     78.2        66.7        87.2
# 5201        55.3       78.5     60.6     78.5        67.2        87.3
# 6249        55.5       78.6     60.8     78.6        67.3        87.4
# 6912        55.7       78.9     61.0     78.9        67.6        87.7
# 4943        55.6       78.9     60.9     78.9        67.5        87.9
# 10625       50.7       76.0     56.6     76.0        64.5        88.0
# 6021        56.0       79.4     61.4     79.4        68.0        88.4
# 4728        56.2       79.6     61.6     79.6        68.3        88.6
# 8233        56.4       80.0     61.8     80.0        68.5        88.9
# 8297        56.4       80.0     61.8     80.0        68.5        88.9
# 11243       51.2       76.8     57.3     76.8        65.2        88.9
# 13117       51.3       77.0     57.4     77.0        65.3        89.0
# 1581        56.5       80.0     61.9     80.0        68.5        89.0
# 1517        56.5       80.0     61.9     80.0        68.5        89.0
# 14225       55.8       79.9     61.3     79.9        68.2        89.0
# 4484        56.4       80.2     61.9     80.2        68.6        89.2
# 4420        56.4       80.2     61.9     80.2        68.6        89.2
# 8634        56.5       80.2     62.0     80.2        68.7        89.3
# 2159        56.7       80.4     62.2     80.4        68.9        89.4
# 9705        56.5       80.4     62.0     80.4        68.8        89.5
# 13647       51.7       77.5     57.8     77.5        65.8        89.6
# 5397        56.7       80.5     62.2     80.5        68.9        89.6
# 12403       51.6       77.6     57.8     77.6        65.8        89.7
# 13353       51.8       77.8     58.0     77.8        66.0        90.0
# 5693        57.1       80.9     62.5     80.9        69.3        90.0
# 9346        56.9       80.9     62.4     80.9        69.2        90.0
#
#        max_salary  entry_mean  mid_mean  senior_mean
# 10622        82.1       62.55     65.00        72.45
# 5046         85.2       65.30     67.90        75.40
# 7911         86.8       66.55     69.15        76.80
# 3439         87.2       66.40     69.10        76.95
# 3375         87.2       66.40     69.10        76.95
# 5201         87.3       66.90     69.55        77.25
# 6249         87.4       67.05     69.70        77.35
# 6912         87.7       67.30     69.95        77.65
# 4943         87.9       67.25     69.90        77.70
# 10625        88.0       63.35     66.30        76.25
# 6021         88.4       67.70     70.40        78.20
# 4728         88.6       67.90     70.60        78.45
# 8233         88.9       68.20     70.90        78.70
# 8297         88.9       68.20     70.90        78.70
# 11243        88.9       64.00     67.05        77.05
# 13117        89.0       64.15     67.20        77.15
# 1581         89.0       68.25     70.95        78.75
# 1517         89.0       68.25     70.95        78.75
# 14225        89.0       67.85     70.60        78.60
# 4484         89.2       68.30     71.05        78.90
# 4420         89.2       68.30     71.05        78.90
# 8634         89.3       68.35     71.10        79.00
# 2159         89.4       68.55     71.30        79.15
# 9705         89.5       68.45     71.20        79.15
# 13647        89.6       64.60     67.65        77.70
# 5397         89.6       68.60     71.35        79.25
# 12403        89.7       64.60     67.70        77.75
# 13353        90.0       64.80     67.90        78.00
# 5693         90.0       69.00     71.70        79.65
# 9346         90.0       68.90     71.65        79.60

# %% [markdown]
# ### Get the job that pays the most in Quebec

# %%
top_quebec_jobs=df_sorted[df_sorted['province'].str.contains('québec', case=False)]
top_quebec_jobs.head(30)
# Out:
#       province                            region  \
# 14126   québec                          montréal
# 13548   québec      montérégie - les maskoutains
# 12671   québec                          mauricie
# 11905   québec                             laval
# 14543   québec                         outaouais
# 10518   québec                  centre-du-québec
# 11144   québec                            estrie
# 12303   québec                          mauricie
# 14635   québec           saguenay-lac-saint-jean
# 11429   québec                        lanaudière
# 11573   québec                       laurentides
# 10128   québec                         cambridge
# 10519   québec                  centre-du-québec
# 11145   québec                            estrie
# 12304   québec                          mauricie
# 14636   québec           saguenay-lac-saint-jean
# 14127   québec                          montréal
# 12672   québec                          mauricie
# 11906   québec                             laval
# 14544   québec                         outaouais
# 10129   québec                         cambridge
# 11574   québec                       laurentides
# 14260   québec                          montréal
# 12026   québec                             laval
# 12801   québec                          mauricie
# 13944   québec  montérégie - vaudreuil-soulanges
# 11697   québec                       laurentides
# 10259   québec                         cambridge
# 13385   québec     montérégie - la haute-yamaska
# 11273   québec                            estrie
#
#                                           job        entry          mid  \
# 14126  chef/cheffe de la direction financière  176,5-451,3  258,6-451,3
# 13548  chef/cheffe de la direction financière  175,3-448,2  256,9-448,2
# 12671  chef/cheffe de la direction financière  175,3-448,2  256,9-448,2
# 11905  chef/cheffe de la direction financière  174,1-447,0  255,5-447,0
# 14543  chef/cheffe de la direction financière  154,3-415,8  230,8-415,8
# 10518  chef/cheffe de la direction financière  155,8-409,7  226,2-409,7
# 11144  chef/cheffe de la direction financière  155,8-409,7  226,2-409,7
# 12303  chef/cheffe de la direction financière  155,8-409,7  226,2-409,7
# 14635  chef/cheffe de la direction financière  155,8-409,7  226,2-409,7
# 11429  chef/cheffe de la direction financière  160,3-247,1  177,1-247,1
# 11573  chef/cheffe de la direction financière  148,1-403,9  222,3-403,9
# 10128  chef/cheffe de la direction financière  140,1-401,3  217,2-401,3
# 10519             vice-président des finances  149,3-376,2  217,5-376,2
# 11145             vice-président des finances  149,3-376,2  217,5-376,2
# 12304             vice-président des finances  149,3-376,2  217,5-376,2
# 14636             vice-président des finances  149,3-376,2  217,5-376,2
# 14127             vice-président des finances  164,5-316,4  182,5-316,4
# 12672             vice-président des finances  163,5-316,2  182,3-316,2
# 11906             vice-président des finances  157,0-313,0  180,0-313,0
# 14544             vice-président des finances  142,1-279,2  155,3-279,2
# 10129             vice-président des finances  126,3-277,3  153,4-277,3
# 11574             vice-président des finances  132,6-269,9  149,2-269,9
# 14260           vice-président·e du marketing  104,3-264,8  145,9-264,8
# 12026                          guide salarial  103,1-262,6  144,4-262,6
# 12801           vice-président·e du marketing  102,3-260,8  143,2-260,8
# 13944           vice-président·e du marketing  102,2-258,9  142,6-258,9
# 11697           vice-président·e du marketing  100,5-256,9  140,8-256,9
# 10259           vice-président·e du marketing   99,4-255,7  139,6-255,7
# 13385           vice-président·e du marketing   97,3-251,3  136,7-251,3
# 11273           vice-président·e du marketing   96,5-250,7  136,0-250,7
#
#             senior  entry_min  entry_max  mid_min  mid_max  senior_min  \
# 14126  360,9-629,4      176.5      451.3    258.6    451.3       360.9
# 13548  358,5-624,4      175.3      448.2    256.9    448.2       358.5
# 12671  358,5-624,4      175.3      448.2    256.9    448.2       358.5
# 11905  357,2-624,0      174.1      447.0    255.5    447.0       357.2
# 14543  328,3-590,9      154.3      415.8    230.8    415.8       328.3
# 10518  322,8-583,8      155.8      409.7    226.2    409.7       322.8
# 11144  322,8-583,8      155.8      409.7    226.2    409.7       322.8
# 12303  322,8-583,8      155.8      409.7    226.2    409.7       322.8
# 14635  322,8-583,8      155.8      409.7    226.2    409.7       322.8
# 11429  320,4-580,7      160.3      247.1    177.1    247.1       320.4
# 11573  317,9-576,8      148.1      403.9    222.3    403.9       317.9
# 10128  314,2-576,2      140.1      401.3    217.2    401.3       314.2
# 10519  294,0-552,6      149.3      376.2    217.5    376.2       294.0
# 11145  294,0-552,6      149.3      376.2    217.5    376.2       294.0
# 12304  294,0-552,6      149.3      376.2    217.5    376.2       294.0
# 14636  294,0-552,6      149.3      376.2    217.5    376.2       294.0
# 14127  252,7-438,3      164.5      316.4    182.5    316.4       252.7
# 12672  251,6-437,3      163.5      316.2    182.3    316.2       251.6
# 11906  249,7-434,2      157.0      313.0    180.0    313.0       249.7
# 14544  219,7-395,7      142.1      279.2    155.3    279.2       219.7
# 10129  217,9-393,7      126.3      277.3    153.4    277.3       217.9
# 11574  211,7-384,5      132.6      269.9    149.2    269.9       211.7
# 14260  198,3-359,5      104.3      264.8    145.9    264.8       198.3
# 12026  196,6-356,6      103.1      262.6    144.4    262.6       196.6
# 12801  195,1-354,3      102.3      260.8    143.2    260.8       195.1
# 13944  193,7-352,1      102.2      258.9    142.6    258.9       193.7
# 11697  191,9-349,7      100.5      256.9    140.8    256.9       191.9
# 10259  190,7-348,7       99.4      255.7    139.6    255.7       190.7
# 13385  187,0-343,4       97.3      251.3    136.7    251.3       187.0
# 11273  186,4-342,9       96.5      250.7    136.0    250.7       186.4
#
#        senior_max  max_salary  entry_mean  mid_mean  senior_mean
# 14126       629.4       629.4      313.90    354.95       495.15
# 13548       624.4       624.4      311.75    352.55       491.45
# 12671       624.4       624.4      311.75    352.55       491.45
# 11905       624.0       624.0      310.55    351.25       490.60
# 14543       590.9       590.9      285.05    323.30       459.60
# 10518       583.8       583.8      282.75    317.95       453.30
# 11144       583.8       583.8      282.75    317.95       453.30
# 12303       583.8       583.8      282.75    317.95       453.30
# 14635       583.8       583.8      282.75    317.95       453.30
# 11429       580.7       580.7      203.70    212.10       450.55
# 11573       576.8       576.8      276.00    313.10       447.35
# 10128       576.2       576.2      270.70    309.25       445.20
# 10519       552.6       552.6      262.75    296.85       423.30
# 11145       552.6       552.6      262.75    296.85       423.30
# 12304       552.6       552.6      262.75    296.85       423.30
# 14636       552.6       552.6      262.75    296.85       423.30
# 14127       438.3       438.3      240.45    249.45       345.50
# 12672       437.3       437.3      239.85    249.25       344.45
# 11906       434.2       434.2      235.00    246.50       341.95
# 14544       395.7       395.7      210.65    217.25       307.70
# 10129       393.7       393.7      201.80    215.35       305.80
# 11574       384.5       384.5      201.25    209.55       298.10
# 14260       359.5       359.5      184.55    205.35       278.90
# 12026       356.6       356.6      182.85    203.50       276.60
# 12801       354.3       354.3      181.55    202.00       274.70
# 13944       352.1       352.1      180.55    200.75       272.90
# 11697       349.7       349.7      178.70    198.85       270.80
# 10259       348.7       348.7      177.55    197.65       269.70
# 13385       343.4       343.4      174.30    194.00       265.20
# 11273       342.9       342.9      173.60    193.35       264.65

# %%
top_montreal_jobs=df_sorted[df_sorted['region'].str.contains('montréal', case=False)]
top_montreal_jobs.head(30)
# Out:
#       province    region                                                job  \
# 14126   québec  montréal             chef/cheffe de la direction financière
# 14127   québec  montréal                        vice-président des finances
# 14260   québec  montréal                      vice-président·e du marketing
# 14303   québec  montréal    vice-président·e des ressources humaines / chro
# 14258   québec  montréal                  vice président marketing & ventes
# 14124   québec  montréal  directeur/directrice - budget et performance f...
# 14125   québec  montréal                  directeur/directrice des finances
# 14128   québec  montréal                vice-président·e de l’audit interne
# 14259   québec  montréal                vice-président·e des communications
# 14138   québec  montréal                directeur/directrice des opérations
# 14175   québec  montréal                directeur/directrice des opérations
# 14498   québec  montréal                        vice-président·e des ventes
# 14492   québec  montréal       directeur du développement et de l’ingénérie
# 14131   québec  montréal                      directeur de la planification
# 14172   québec  montréal            directeur/directrice de la construction
# 14297   québec  montréal    directeur/directrice de la rémunération globale
# 14130   québec  montréal         directeur de la chaîne d’approvisionnement
# 14134   québec  montréal                directeur/directrice de fabrication
# 14136   québec  montréal        directeur/directrice de l’approvisionnement
# 14441   québec  montréal  directeur/directrice des technologies de l’inf...
# 14453   québec  montréal                           chef du bureau de projet
# 14299   québec  montréal       directeur/directrice des ressources humaines
# 14274   québec  montréal                             directeur·e e-commerce
# 14301   québec  montréal                directeur/directrice, opérations rh
# 14298   québec  montréal   directeur/directrice de l’acquisition de talents
# 14139   québec  montréal                                directeur·e qualité
# 14133   québec  montréal                       directeur/directrice d’usine
# 14300   québec  montréal  directeur/directrice développement des compéte...
# 14333   québec  montréal                             gérant de la pharmacie
# 14137   québec  montréal                    directeur/directrice de projets
#
#              entry          mid       senior  entry_min  entry_max  mid_min  \
# 14126  176,5-451,3  258,6-451,3  360,9-629,4      176.5      451.3    258.6
# 14127  164,5-316,4  182,5-316,4  252,7-438,3      164.5      316.4    182.5
# 14260  104,3-264,8  145,9-264,8  198,3-359,5      104.3      264.8    145.9
# 14303  129,0-269,5  162,7-269,5  201,1-333,0      129.0      269.5    162.7
# 14258   92,7-235,6  129,7-235,6  176,9-320,7       92.7      235.6    129.7
# 14124  157,5-261,8  200,1-261,8  243,3-318,1      157.5      261.8    200.1
# 14125  152,8-257,3  196,6-257,3  238,7-312,2      152.8      257.3    196.6
# 14128  153,6-254,8  192,5-254,8  233,5-308,9      153.6      254.8    192.5
# 14259  105,1-217,9  142,4-217,9  183,6-280,5      105.1      217.9    142.4
# 14138  121,9-215,0  165,0-215,0  203,8-272,7      121.9      215.0    165.0
# 14175  121,9-215,0  160,7-215,0  203,8-272,7      121.9      215.0    160.7
# 14498  136,7-218,2  169,1-218,2  208,3-268,7      136.7      218.2    169.1
# 14492  104,8-201,4  140,6-201,4  185,5-265,3      104.8      201.4    140.6
# 14131  129,5-206,5  160,5-206,5  197,0-253,6      129.5      206.5    160.5
# 14172  117,1-204,1  156,9-204,1  194,6-253,4      117.1      204.1    156.9
# 14297  122,7-203,3  158,1-203,3  193,1-248,6      122.7      203.3    158.1
# 14130  121,0-205,0  161,0-205,0  190,0-247,0      121.0      205.0    161.0
# 14134  128,0-197,6  164,4-197,6  201,6-242,4      128.0      197.6    164.4
# 14136  116,3-200,6  154,2-200,6  185,8-242,0      116.3      200.6    154.2
# 14441  116,7-193,7  147,3-193,7  182,2-240,0      116.7      193.7    147.3
# 14453  116,7-193,7  147,3-193,7  182,2-240,0      116.7      193.7    147.3
# 14299  107,2-186,4  136,9-186,4  168,7-230,1      107.2      186.4    136.9
# 14274  113,0-178,5  143,3-178,5  181,5-225,8      113.0      178.5    143.3
# 14301   97,6-180,1  127,5-180,1  159,0-224,1       97.6      180.1    127.5
# 14298  102,3-177,0  129,8-177,0  158,0-215,1      102.3      177.0    129.8
# 14139  103,9-175,9  132,1-175,9  160,8-214,1      103.9      175.9    132.1
# 14133  111,0-184,8  133,3-184,8  157,7-214,0      111.0      184.8    133.3
# 14300  110,0-169,1  137,6-169,1  173,6-213,6      110.0      169.1    137.6
# 14333  121,1-182,8  137,0-182,8  154,6-205,0      121.1      182.8    137.0
# 14137  108,2-166,0  136,5-166,0  168,0-204,1      108.2      166.0    136.5
#
#        mid_max  senior_min  senior_max  max_salary  entry_mean  mid_mean  \
# 14126    451.3       360.9       629.4       629.4      313.90    354.95
# 14127    316.4       252.7       438.3       438.3      240.45    249.45
# 14260    264.8       198.3       359.5       359.5      184.55    205.35
# 14303    269.5       201.1       333.0       333.0      199.25    216.10
# 14258    235.6       176.9       320.7       320.7      164.15    182.65
# 14124    261.8       243.3       318.1       318.1      209.65    230.95
# 14125    257.3       238.7       312.2       312.2      205.05    226.95
# 14128    254.8       233.5       308.9       308.9      204.20    223.65
# 14259    217.9       183.6       280.5       280.5      161.50    180.15
# 14138    215.0       203.8       272.7       272.7      168.45    190.00
# 14175    215.0       203.8       272.7       272.7      168.45    187.85
# 14498    218.2       208.3       268.7       268.7      177.45    193.65
# 14492    201.4       185.5       265.3       265.3      153.10    171.00
# 14131    206.5       197.0       253.6       253.6      168.00    183.50
# 14172    204.1       194.6       253.4       253.4      160.60    180.50
# 14297    203.3       193.1       248.6       248.6      163.00    180.70
# 14130    205.0       190.0       247.0       247.0      163.00    183.00
# 14134    197.6       201.6       242.4       242.4      162.80    181.00
# 14136    200.6       185.8       242.0       242.0      158.45    177.40
# 14441    193.7       182.2       240.0       240.0      155.20    170.50
# 14453    193.7       182.2       240.0       240.0      155.20    170.50
# 14299    186.4       168.7       230.1       230.1      146.80    161.65
# 14274    178.5       181.5       225.8       225.8      145.75    160.90
# 14301    180.1       159.0       224.1       224.1      138.85    153.80
# 14298    177.0       158.0       215.1       215.1      139.65    153.40
# 14139    175.9       160.8       214.1       214.1      139.90    154.00
# 14133    184.8       157.7       214.0       214.0      147.90    159.05
# 14300    169.1       173.6       213.6       213.6      139.55    153.35
# 14333    182.8       154.6       205.0       205.0      151.95    159.90
# 14137    166.0       168.0       204.1       204.1      137.10    151.25
#
#        senior_mean
# 14126       495.15
# 14127       345.50
# 14260       278.90
# 14303       267.05
# 14258       248.80
# 14124       280.70
# 14125       275.45
# 14128       271.20
# 14259       232.05
# 14138       238.25
# 14175       238.25
# 14498       238.50
# 14492       225.40
# 14131       225.30
# 14172       224.00
# 14297       220.85
# 14130       218.50
# 14134       222.00
# 14136       213.90
# 14441       211.10
# 14453       211.10
# 14299       199.40
# 14274       203.65
# 14301       191.55
# 14298       186.55
# 14139       187.45
# 14133       185.85
# 14300       193.60
# 14333       179.80
# 14137       186.05

# %%
# make a function to compare a specific job in a specific province
def compare_job_province(job, province):
    df_filtered = df[(df['province'] == province) & (df['job'] == job)]
    df_grouped = df_filtered.groupby(['job', 'region'])['mid_mean'].mean().reset_index()
    return df_grouped.sort_values('mid_mean', ascending=False)

# %%
# "ontario", "québec", "british columbia", "alberta", "manitoba", "saskatchewan", "nova scotia", "new brunswick", "newfoundland & labrador", "prince edward island"
df_job_province = compare_job_province('architecte infonuagique', 'québec')
df_job_province
# Out:
#                        job                   region    mid_mean
# 4  architecte infonuagique                 montréal  135.700000
# 2  architecte infonuagique                    laval  134.200000
# 1  architecte infonuagique     chaudière-appalaches  128.500000
# 3  architecte infonuagique                 mauricie  121.225000
# 5  architecte infonuagique  saguenay-lac-saint-jean  112.983333
# 0  architecte infonuagique                cambridge  111.500000

# %% [markdown]
# ## Across the country

# %%
# function to compare a specific job in a all provinces
def compare_job_all_provinces(job):
    df_filtered = df[(df['job'] == job)]
    df_grouped = df_filtered.groupby(['job', 'province'])['mid_mean'].mean().reset_index()
    return df_grouped.sort_values('mid_mean', ascending=False)

# %%
df_job_all_provinces = compare_job_all_provinces('architecte infonuagique')
df_job_all_provinces
# Out:
#                        job                 province    mid_mean
# 0  architecte infonuagique                  alberta  125.875000
# 1  architecte infonuagique         british columbia  125.300000
# 8  architecte infonuagique                   québec  121.255556
# 6  architecte infonuagique                  ontario  119.028571
# 4  architecte infonuagique  newfoundland & labrador  116.750000
# 2  architecte infonuagique                 manitoba  114.000000
# 5  architecte infonuagique              nova scotia  113.600000
# 3  architecte infonuagique            new brunswick  111.016667
# 7  architecte infonuagique     prince edward island  109.050000

# %% [markdown]
# ### Detailled breakdown of the salary by province

# %%
# Get the unique provinces
provinces = df['province'].unique()

# Define the job to compare
job = 'architecte infonuagique'

# Loop over the provinces and compare the job in each province
for province in provinces:
    # Filter the dataframe by province and job
    df_filtered = df[(df['province'] == province) & (df['job'] == job)]

    # Group the resulting dataframe by job and region, and calculate the mean mid salary
    df_grouped = df_filtered.groupby(['job', 'region'])['mid_mean'].mean().reset_index()

    # Sort the grouped dataframe by the mid salary in descending order
    df_sorted = df_grouped.sort_values('mid_mean', ascending=False)

    # Print the sorted dataframe with the province name
    print(f'{province.capitalize()}:')
    print(df_sorted)
    print()
# Out:
# Alberta:
#                        job    region  mid_mean
# 0  architecte infonuagique  red deer   125.875
#
# British columbia:
#                        job         region  mid_mean
# 0  architecte infonuagique  fraser valley     125.3
#
# Prince edward island:
#                        job                  region  mid_mean
# 0  architecte infonuagique  queens - charlottetown    109.05
#
# Manitoba:
#                        job                  region  mid_mean
# 0  architecte infonuagique  queens - charlottetown     114.0
#
# New brunswick:
#                        job      region    mid_mean
# 0  architecte infonuagique  saint john  111.016667
#
# Nova scotia:
#                        job      region  mid_mean
# 0  architecte infonuagique  saint john     113.6
#
# Ontario:
#                        job     region    mid_mean
# 0  architecte infonuagique  cambridge  119.028571
#
# Québec:
#                        job                   region    mid_mean
# 4  architecte infonuagique                 montréal  135.700000
# 2  architecte infonuagique                    laval  134.200000
# 1  architecte infonuagique     chaudière-appalaches  128.500000
# 3  architecte infonuagique                 mauricie  121.225000
# 5  architecte infonuagique  saguenay-lac-saint-jean  112.983333
# 0  architecte infonuagique                cambridge  111.500000
#
# Newfoundland & labrador:
#                        job                   region  mid_mean
# 0  architecte infonuagique  saguenay-lac-saint-jean    116.75

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Let's find the job that has the biggest difference across the country

# %%
#function to find the job with the largest difference, the user can choose between entry, mid or senior
def find_job_with_biggest_diff(level):
    #if level is not entry, mid or senior, return an error
    if level not in ['entry_mean', 'mid_mean', 'senior_mean']:
        return 'Error: level must be entry_mean, mid_mean or senior_mean'
    # Group by the 'job' column and find the difference between the maximum and minimum values of the 'mid' column for each group
    job_diffs = df.groupby('job')[[level]].apply(lambda x: (x.max() - x.min()).sum())

    # Find the job with the largest overall salary difference
    max_diff_job = job_diffs.idxmax()

    # Print the result
    print(f"The job with the largest overall salary difference is: {max_diff_job}")

# %%
find_job_with_biggest_diff('entry_mean')
# Out:
# The job with the largest overall salary difference is: guide salarial

# %%
job_diffs = df.groupby('job')[["mid_mean"]].apply(lambda x: (x.max() - x.min()).sum())
job_diffs_df = job_diffs.to_frame('Difference')

# %%
#sort the dataframe by the difference
job_diffs_df_sorted = job_diffs_df.sort_values('Difference', ascending=False)   
job_diffs_df_sorted.head(30)
# Out:
#                                                     Difference
# job
# guide salarial                                          185.40
# chef/cheffe de la direction financière                  144.60
# vice-président des finances                              87.30
# directeur/directrice général                             87.20
# coordinateur de projet                                   79.90
# gestionnaire des contrats                                77.65
# gestionnaire du contrôle d’inventaire                    68.40
# consultant workday                                       65.60
# chef du bureau de projet                                 63.00
# gestionnaire de programme                                61.00
# directeur/directrice de l’ingénierie                     60.65
# directeur de la chaîne d’approvisionnement               56.60
# aviseur technique                                        55.15
# consultant en sécurité infonuagique                      54.30
# architecte (solutions/technique)                         52.80
# architecte soa                                           52.55
# directeur des opérations de centre d’appels bil...       51.65
# gestionnaire d’atelier de soudure                        50.70
# directeur/directrice de la santé et sécurité             46.55
# vice-président·e des ressources humaines / chro          46.30
# responsable d’équipe                                     44.65
# directeur/directrice - budget et performance fi...       43.75
# ingénieur·e d’applications                               43.35
# directeur/directrice des finances                        43.20
# chef d’équipe mécanicien                                 42.60
# directeur/directrice de la rémunération globale          42.35
# gestionnaire des achats                                  42.35
# directeur/directrice de l’approvisionnement              41.90
# directeur de la planification                            41.35
# directeur/directrice de fabrication                      41.15
