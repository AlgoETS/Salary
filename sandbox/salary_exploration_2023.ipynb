# %%
# read pickle file
# get current working directory
import os
os.getcwd()
import pickle
import pandas as pd
import polars as pl
with open("data/pickle/salary_guide_2023.pkl", 'rb') as f:
     data = pickle.load(f)

# load to dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#            province                       region  \
# 0                    calgary metropolitan region
# 1                    calgary metropolitan region
# 2                    calgary metropolitan region
# 3                    calgary metropolitan region
# 4                    calgary metropolitan region
# ...             ...                          ...
# 18587  saskatchewan  saskatoon metropolitan area
# 18588  saskatchewan  saskatoon metropolitan area
# 18589  saskatchewan  saskatoon metropolitan area
# 18590  saskatchewan  saskatoon metropolitan area
# 18591  saskatchewan  saskatoon metropolitan area
#
#                                     job       entry          mid       senior
# 0              administrative assistant   43.6-56.4    49.9-61.3    55.2-66.7
# 1                administrative manager   65.2-74.3    71.1-81.9    78.7-94.6
# 2                       buyer assistant   45.5-57.2    53.4-66.1    58.8-72.2
# 3                     claims supervisor   70.1-82.0   78.5-104.9   89.0-119.7
# 4               contracts administrator   80.4-98.8   87.7-109.3   91.2-120.5
# ...                                 ...         ...          ...          ...
# 18587               project coordinator   65.3-81.5    72.7-92.4   81.9-104.2
# 18588  project manager (infrastructure)  95.9-130.1  108.8-150.5  124.8-172.7
# 18589        project manager (software)  95.0-126.2  106.4-144.0  120.5-163.4
# 18590                      scrum master   72.7-95.2   82.3-109.5   93.9-125.0
# 18591                  technical writer   58.9-77.2    68.9-91.3   80.3-103.9
#
# [18592 rows x 6 columns]

# %%
# Split the salary ranges into minimum and maximum salaries
df[['entry_min', 'entry_max']] = df['entry'].str.split('-', expand=True).astype(float)
df[['mid_min', 'mid_max']] = df['mid'].str.split('-', expand=True).astype(float)
df[['senior_min', 'senior_max']] = df['senior'].str.split('-', expand=True).astype(float)

# Create a new column with the maximum salary for each job
df['max_salary'] = df[['entry_max', 'mid_max', 'senior_max']].max(axis=1)
#calculate the mean for each level
df['entry_mean'] = df[['entry_min', 'entry_max']].mean(axis=1)
df['mid_mean'] = df[['mid_min', 'mid_max']].mean(axis=1)
df['senior_mean'] = df[['senior_min', 'senior_max']].mean(axis=1)

# Sort the DataFrame by the maximum salary in descending order
df_sorted = df.sort_values('max_salary', ascending=False)

# Get the job that pays the most
job_highest_paid = df_sorted['job'].iloc[0]

print(f"The job that pays the most is {job_highest_paid}")
# Out:
# The job that pays the most is receptionist (bilingual)

# %%
df_sorted.head()
# Out:
#                province                       region  \
# 9602            ontario                simcoe county
# 6860            ontario         greater toronto area
# 11158           ontario                  york region
# 215             alberta  calgary metropolitan region
# 1967   british columbia            greater vancouver
#
#                             job        entry          mid       senior  \
# 9602   receptionist (bilingual)    50.3-58.7    56.1-66.8   63.1-713.0
# 6860    chief financial officer  172.6-296.8  250.7-430.1  346.3-594.1
# 11158   chief financial officer  170.0-292.4  246.7-424.8  341.5-587.9
# 215     chief financial officer  161.5-281.9  236.8-414.0  330.7-579.1
# 1967    chief financial officer  163.7-283.5  238.5-414.8  332.1-577.7
#
#        entry_min  entry_max  mid_min  mid_max  senior_min  senior_max  \
# 9602        50.3       58.7     56.1     66.8        63.1       713.0
# 6860       172.6      296.8    250.7    430.1       346.3       594.1
# 11158      170.0      292.4    246.7    424.8       341.5       587.9
# 215        161.5      281.9    236.8    414.0       330.7       579.1
# 1967       163.7      283.5    238.5    414.8       332.1       577.7
#
#        max_salary  entry_mean  mid_mean  senior_mean
# 9602        713.0        54.5     61.45       388.05
# 6860        594.1       234.7    340.40       470.20
# 11158       587.9       231.2    335.75       464.70
# 215         579.1       221.7    325.40       454.90
# 1967        577.7       223.6    326.65       454.90

# %%
df_sorted.head(100)
# Out:
#                province                       region  \
# 9602            ontario                simcoe county
# 6860            ontario         greater toronto area
# 11158           ontario                  york region
# 215             alberta  calgary metropolitan region
# 1967   british columbia            greater vancouver
# ...                 ...                          ...
# 8513            ontario   ottawa metropolitan region
# 8533            ontario   ottawa metropolitan region
# 5513            ontario                durham region
# 5533            ontario                durham region
# 13213            québec                  laurentides
#
#                             job        entry          mid       senior  \
# 9602   receptionist (bilingual)    50.3-58.7    56.1-66.8   63.1-713.0
# 6860    chief financial officer  172.6-296.8  250.7-430.1  346.3-594.1
# 11158   chief financial officer  170.0-292.4  246.7-424.8  341.5-587.9
# 215     chief financial officer  161.5-281.9  236.8-414.0  330.7-579.1
# 1967    chief financial officer  163.7-283.5  238.5-414.8  332.1-577.7
# ...                         ...          ...          ...          ...
# 8513   marketing vice-president  129.4-197.8  180.8-277.3  232.7-357.0
# 8533       sales vice-president  144.0-205.0  193.8-276.8  249.8-356.9
# 5513   marketing vice-president  128.5-196.8  179.8-276.3  231.7-356.2
# 5533       sales vice-president  143.0-204.0  192.9-275.9  248.8-356.1
# 13213    vice president finance  121.4-172.0  136.6-247.2  193.9-352.1
#
#        entry_min  entry_max  mid_min  mid_max  senior_min  senior_max  \
# 9602        50.3       58.7     56.1     66.8        63.1       713.0
# 6860       172.6      296.8    250.7    430.1       346.3       594.1
# 11158      170.0      292.4    246.7    424.8       341.5       587.9
# 215        161.5      281.9    236.8    414.0       330.7       579.1
# 1967       163.7      283.5    238.5    414.8       332.1       577.7
# ...          ...        ...      ...      ...         ...         ...
# 8513       129.4      197.8    180.8    277.3       232.7       357.0
# 8533       144.0      205.0    193.8    276.8       249.8       356.9
# 5513       128.5      196.8    179.8    276.3       231.7       356.2
# 5533       143.0      204.0    192.9    275.9       248.8       356.1
# 13213      121.4      172.0    136.6    247.2       193.9       352.1
#
#        max_salary  entry_mean  mid_mean  senior_mean
# 9602        713.0       54.50     61.45       388.05
# 6860        594.1      234.70    340.40       470.20
# 11158       587.9      231.20    335.75       464.70
# 215         579.1      221.70    325.40       454.90
# 1967        577.7      223.60    326.65       454.90
# ...           ...         ...       ...          ...
# 8513        357.0      163.60    229.05       294.85
# 8533        356.9      174.50    235.30       303.35
# 5513        356.2      162.65    228.05       293.95
# 5533        356.1      173.50    234.40       302.45
# 13213       352.1      146.70    191.90       273.00
#
# [100 rows x 16 columns]

# %% [markdown]
# ### Get the engineering jobs that pay the most

# %%
top_engineers_jobs=df_sorted[df_sorted['job'].str.contains('engineer', case=False)]
top_engineers_jobs.head(30)
# Out:
#                province                       region                  job  \
# 6709            ontario         greater toronto area  engineering manager
# 6967            ontario         greater toronto area  engineering manager
# 6783            ontario         greater toronto area  engineering manager
# 11264           ontario                  york region  engineering manager
# 11121           ontario                  york region  engineering manager
# 5220            ontario                durham region  engineering manager
# 5294            ontario                durham region  engineering manager
# 5465            ontario                durham region  engineering manager
# 867             alberta             northern alberta  engineering manager
# 1087            alberta             northern alberta  engineering manager
# 938             alberta             northern alberta  engineering manager
# 1486            alberta                fort st. john  engineering manager
# 9063            ontario                  peel region  engineering manager
# 8989            ontario                  peel region  engineering manager
# 9244            ontario                  peel region  engineering manager
# 65              alberta  calgary metropolitan region  engineering manager
# 12011            québec         chaudière-appalaches  engineering manager
# 12079            québec         chaudière-appalaches  engineering manager
# 12228            québec         chaudière-appalaches  engineering manager
# 318             alberta  calgary metropolitan region  engineering manager
# 136             alberta  calgary metropolitan region  engineering manager
# 16150            québec                     montréal  engineering manager
# 16219            québec                     montréal  engineering manager
# 16388            québec                     montréal  engineering manager
# 988             alberta             northern alberta     project engineer
# 1072            alberta             northern alberta     project engineer
# 889             alberta             northern alberta     project engineer
# 3088   british columbia                 surrey/delta  engineering manager
# 3017   british columbia                 surrey/delta  engineering manager
# 3207   british columbia                 surrey/delta  engineering manager
#
#              entry          mid       senior  entry_min  entry_max  mid_min  \
# 6709   101.4-136.1  115.8-157.2  133.0-178.0      101.4      136.1    115.8
# 6967   101.4-136.1  115.8-157.2  133.0-178.0      101.4      136.1    115.8
# 6783   101.4-136.1  115.8-157.2  133.0-178.0      101.4      136.1    115.8
# 11264   99.3-133.4  113.5-154.1  130.4-174.4       99.3      133.4    113.5
# 11121   99.3-133.4  113.5-154.1  130.4-174.4       99.3      133.4    113.5
# 5220    98.9-132.7  112.9-153.2  129.7-173.1       98.9      132.7    112.9
# 5294    98.9-132.7  112.9-153.2  129.7-173.1       98.9      132.7    112.9
# 5465    98.9-132.7  112.9-153.2  129.7-173.1       98.9      132.7    112.9
# 867     98.2-130.9  111.8-151.3  128.0-171.4       98.2      130.9    111.8
# 1087    98.2-130.9  111.8-151.3  128.0-171.4       98.2      130.9    111.8
# 938     98.2-130.9  111.8-151.3  128.0-171.4       98.2      130.9    111.8
# 1486    88.2-118.2  100.5-137.1  115.5-170.0       88.2      118.2    100.5
# 9063    94.5-127.2  108.0-147.1  124.3-166.5       94.5      127.2    108.0
# 8989    94.5-127.2  108.0-147.1  124.3-166.5       94.5      127.2    108.0
# 9244    94.5-127.2  108.0-147.1  124.3-166.5       94.5      127.2    108.0
# 65      94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 12011   94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 12079   94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 12228   94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 318     94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 136     94.0-126.1  107.3-146.3  123.3-166.4       94.0      126.1    107.3
# 16150   93.4-126.3  107.1-146.4  123.4-166.1       93.4      126.3    107.1
# 16219   93.4-126.3  107.1-146.4  123.4-166.1       93.4      126.3    107.1
# 16388   93.4-126.3  107.1-146.4  123.4-166.1       93.4      126.3    107.1
# 988    105.9-134.5  114.5-148.1  125.8-164.2      105.9      134.5    114.5
# 1072   105.9-134.5  114.5-148.1  125.8-164.2      105.9      134.5    114.5
# 889    105.9-134.5  114.5-148.1  125.8-164.2      105.9      134.5    114.5
# 3088    93.9-125.6  107.0-145.0  122.8-164.1       93.9      125.6    107.0
# 3017    93.9-125.6  107.0-145.0  122.8-164.1       93.9      125.6    107.0
# 3207    93.9-125.6  107.0-145.0  122.8-164.1       93.9      125.6    107.0
#
#        mid_max  senior_min  senior_max  max_salary  entry_mean  mid_mean  \
# 6709     157.2       133.0       178.0       178.0      118.75    136.50
# 6967     157.2       133.0       178.0       178.0      118.75    136.50
# 6783     157.2       133.0       178.0       178.0      118.75    136.50
# 11264    154.1       130.4       174.4       174.4      116.35    133.80
# 11121    154.1       130.4       174.4       174.4      116.35    133.80
# 5220     153.2       129.7       173.1       173.1      115.80    133.05
# 5294     153.2       129.7       173.1       173.1      115.80    133.05
# 5465     153.2       129.7       173.1       173.1      115.80    133.05
# 867      151.3       128.0       171.4       171.4      114.55    131.55
# 1087     151.3       128.0       171.4       171.4      114.55    131.55
# 938      151.3       128.0       171.4       171.4      114.55    131.55
# 1486     137.1       115.5       170.0       170.0      103.20    118.80
# 9063     147.1       124.3       166.5       166.5      110.85    127.55
# 8989     147.1       124.3       166.5       166.5      110.85    127.55
# 9244     147.1       124.3       166.5       166.5      110.85    127.55
# 65       146.3       123.3       166.4       166.4      110.05    126.80
# 12011    146.3       123.3       166.4       166.4      110.05    126.80
# 12079    146.3       123.3       166.4       166.4      110.05    126.80
# 12228    146.3       123.3       166.4       166.4      110.05    126.80
# 318      146.3       123.3       166.4       166.4      110.05    126.80
# 136      146.3       123.3       166.4       166.4      110.05    126.80
# 16150    146.4       123.4       166.1       166.1      109.85    126.75
# 16219    146.4       123.4       166.1       166.1      109.85    126.75
# 16388    146.4       123.4       166.1       166.1      109.85    126.75
# 988      148.1       125.8       164.2       164.2      120.20    131.30
# 1072     148.1       125.8       164.2       164.2      120.20    131.30
# 889      148.1       125.8       164.2       164.2      120.20    131.30
# 3088     145.0       122.8       164.1       164.1      109.75    126.00
# 3017     145.0       122.8       164.1       164.1      109.75    126.00
# 3207     145.0       122.8       164.1       164.1      109.75    126.00
#
#        senior_mean
# 6709        155.50
# 6967        155.50
# 6783        155.50
# 11264       152.40
# 11121       152.40
# 5220        151.40
# 5294        151.40
# 5465        151.40
# 867         149.70
# 1087        149.70
# 938         149.70
# 1486        142.75
# 9063        145.40
# 8989        145.40
# 9244        145.40
# 65          144.85
# 12011       144.85
# 12079       144.85
# 12228       144.85
# 318         144.85
# 136         144.85
# 16150       144.75
# 16219       144.75
# 16388       144.75
# 988         145.00
# 1072        145.00
# 889         145.00
# 3088        143.45
# 3017        143.45
# 3207        143.45

# %% [markdown]
# ### get the engineers jobs that pay the least

# %%
worst_engineers_jobs=top_engineers_jobs.sort_values('max_salary', ascending=True)
worst_engineers_jobs.head(30)
# Out:
# 14647       375.1       375.1      164.85    226.90       292.15
# 14184       374.7       374.7      174.35    251.55       319.85
# 15304       372.7       372.7      173.15    250.05       318.05
# 16049       372.5       372.5      163.75    225.15       290.00
# 12581       372.3       372.3      172.10    249.20       317.45
# 15697       371.3       371.3      172.70    249.10       316.85
# 14914       370.9       370.9      171.85    248.55       316.35
# 17330       369.2       369.2      161.15    222.30       286.95
# 16889       367.6       367.6      159.65    220.80       285.40

# %%
# make a function to compare a specific job in a specific province
def compare_job_province(job, province):
    df_filtered = df[(df['province'] == province) & (df['job'] == job)]
    df_grouped = df_filtered.groupby(['job', 'region'])['mid_mean'].mean().reset_index()
    return df_grouped.sort_values('mid_mean', ascending=False)

# %%
# "ontario", "québec", "british columbia", "alberta", "manitoba", "saskatchewan", "nova scotia", "new brunswick", "newfoundland & labrador", "prince edward island"
df_job_province = compare_job_province('cloud architect', 'québec')
df_job_province
# Out:
#                job                   region  mid_mean
# 3  cloud architect                 montréal    127.65
# 2  cloud architect                    laval    125.80
# 5  cloud architect  saguenay-lac-saint-jean    108.70
# 1  cloud architect              laurentides    108.25
# 4  cloud architect         national capital    108.25
# 0  cloud architect                   estrie    105.20

# %% [markdown]
# ## Across the country

# %%
# function to compare a specific job in a all provinces
def compare_job_all_provinces(job):
    df_filtered = df[(df['job'] == job)]
    df_grouped = df_filtered.groupby(['job', 'province'])['mid_mean'].mean().reset_index()
    return df_grouped.sort_values('mid_mean', ascending=False)

# %%
df_job_all_provinces = compare_job_all_provinces('cloud architect')
df_job_all_provinces
# Out:
#                job                 province    mid_mean
# 0  cloud architect                  alberta  123.800000
# 1  cloud architect         british columbia  117.080000
# 6  cloud architect                  ontario  117.031250
# 9  cloud architect             saskatchewan  116.150000
# 4  cloud architect  newfoundland & labrador  115.900000
# 8  cloud architect                   québec  113.975000
# 2  cloud architect                 manitoba  111.000000
# 5  cloud architect              nova scotia  110.050000
# 3  cloud architect            new brunswick  108.116667
# 7  cloud architect     prince edward island  106.200000

# %% [markdown]
# ### Detailled breakdown of the salary by province

# %%
# Get the unique provinces
provinces = df['province'].unique()

# Define the job to compare
job = 'cloud architect'

# Loop over the provinces and compare the job in each province
for province in provinces:
    # Filter the dataframe by province and job
    df_filtered = df[(df['province'] == province) & (df['job'] == job)]

    # Group the resulting dataframe by job and region, and calculate the mean mid salary
    df_grouped = df_filtered.groupby(['job', 'region'])['mid_mean'].mean().reset_index()

    # Sort the grouped dataframe by the mid salary in descending order
    df_sorted = df_grouped.sort_values('mid_mean', ascending=False)

    # Print the sorted dataframe with the province name
    print(f'{province.capitalize()}:')
    print(df_sorted)
    print()
# Out:
# :
# Empty DataFrame
# Columns: [job, region, mid_mean]
# Index: []
#
# Alberta:
#                job                        region  mid_mean
# 0  cloud architect   calgary metropolitan region    126.75
# 1  cloud architect  edmonton metropolitan region    120.85
#
# British columbia:
#                job             region  mid_mean
# 1  cloud architect  greater vancouver    130.40
# 4  cloud architect      prince george    114.65
# 2  cloud architect   greater victoria    114.30
# 0  cloud architect      fraser valley    113.30
# 3  cloud architect            kelowna    112.75
#
# Manitoba:
#                job                        region  mid_mean
# 0  cloud architect  winnipeg metropolitan region     111.0
#
# New brunswick:
#                job           region  mid_mean
# 1  cloud architect       saint john    109.10
# 2  cloud architect      york region    108.10
# 0  cloud architect  greater moncton    107.15
#
# Newfoundland & labrador:
#                job                       region  mid_mean
# 0  cloud architect  conception bay - st. john’s     115.9
#
# Nova scotia:
#                job           region  mid_mean
# 0  cloud architect  greater halifax    110.05
#
# Ontario:
#                job                      region  mid_mean
# 1  cloud architect        greater toronto area    136.25
# 4  cloud architect  ottawa metropolitan region    120.70
# 7  cloud architect           wellington county    114.85
# 0  cloud architect       greater hamilton area    114.55
# 5  cloud architect               simcoe county    114.45
# 6  cloud architect             waterloo region    113.70
# 2  cloud architect                 london area    111.60
# 3  cloud architect              niagara region    110.15
#
# Prince edward island:
#                job                  region  mid_mean
# 0  cloud architect  queens - charlottetown     106.2
#
# Québec:
#                job                   region  mid_mean
# 3  cloud architect                 montréal    127.65
# 2  cloud architect                    laval    125.80
# 5  cloud architect  saguenay-lac-saint-jean    108.70
# 1  cloud architect              laurentides    108.25
# 4  cloud architect         national capital    108.25
# 0  cloud architect                   estrie    105.20
#
# Saskatchewan:
#                job                       region  mid_mean
# 0  cloud architect     regina metropolitan area    116.65
# 1  cloud architect  saskatoon metropolitan area    115.65

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Let's find the job that has the biggest difference across the country

# %%
#function to find the job with the largest difference, the user can choose between entry, mid or senior
def find_job_with_biggest_diff(level):
    #if level is not entry, mid or senior, return an error
    if level not in ['entry_mean', 'mid_mean', 'senior_mean']:
        return 'Error: level must be entry_mean, mid_mean or senior_mean'
    # Group by the 'job' column and find the difference between the maximum and minimum values of the 'mid' column for each group
    job_diffs = df.groupby('job')[[level]].apply(lambda x: (x.max() - x.min()).sum())

    # Find the job with the largest overall salary difference
    max_diff_job = job_diffs.idxmax()

    # Print the result
    print(f"The job with the largest overall salary difference is: {max_diff_job}")

# %%
find_job_with_biggest_diff('entry_mean')
# Out:
# The job with the largest overall salary difference is: head of workshop and assembly

# %%
job_diffs = df.groupby('job')[["mid_mean"]].apply(lambda x: (x.max() - x.min()).sum())
job_diffs_df = job_diffs.to_frame('Difference')

# %%
#sort the dataframe by the difference
job_diffs_df_sorted = job_diffs_df.sort_values('Difference', ascending=False)   
job_diffs_df_sorted.head(30)
# Out:
#                                           Difference
# job
# head of workshop and assembly                 206.50
# chief financial officer                       146.15
# project coordinator                            90.90
# general manager                                85.35
# contracts administrator                        84.00
# vice president finance                         79.95
# data entry clerk                               74.00
# manufacturing director                         73.65
# inventory control manager                      70.65
# parts manager                                  68.95
# program manager                                62.55
# director of operations                         59.60
# site supervisor                                58.60
# property manager                               52.55
# transportation manager                         51.80
# materials manager                              51.10
# director - financial planning & analysis       50.15
# finance director                               49.45
# qa/qc inspector                                48.95
# claims supervisor                              48.20
# office/operations manager                      47.55
# executive assistant                            45.95
# administrative manager                         44.20
# vice-president internal audit                  43.25
# health and safety manager                      42.55
# vice president human resources / chro          42.35
# hr manager                                     41.40
# planner/scheduler                              40.85
# procurement director                           40.35
# supply chain manager                           40.00
